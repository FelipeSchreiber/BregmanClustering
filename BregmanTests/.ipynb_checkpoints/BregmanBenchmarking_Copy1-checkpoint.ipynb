# %%
# !pip install --upgrade --force-reinstall git+https://github.com/FelipeSchreiber/BregmanClustering.git --no-deps
# !pip install torch_geometric 
### Comment line below if in Google Colab environment
import os
from sys import platform
if platform == "win32":
    os.chmod("C:\\Users\\schre\\.conda\\envs\\pydml\\lib\\site-packages\\BregmanTests/install_algos.sh",777)
    os.environ["R_HOME"] = r"C:\\Program Files\R\R-4.2.3"
else:
    ### Uncomment line below if in Google Colab environment
    # !chmod 777 /usr/local/lib/python3.9/dist-packages/BregmanTests/install_algos.sh
    ### Done
# !pip install rpy2==3.5.1
# Out:
# Collecting git+https://github.com/FelipeSchreiber/BregmanClustering.git
#   Cloning https://github.com/FelipeSchreiber/BregmanClustering.git to c:\users\schre\appdata\local\temp\pip-req-build-dvyvlste
#   Resolved https://github.com/FelipeSchreiber/BregmanClustering.git to commit fd4e218f097ef4dcdbb02744d69e8b70775de354
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: bregClust
#   Building wheel for bregClust (setup.py): started
#   Building wheel for bregClust (setup.py): finished with status 'done'
#   Created wheel for bregClust: filename=bregClust-1.0-py3-none-any.whl size=28645 sha256=4330043eef748d14548982f5de710219b85c6d8aa4b810e2f0736e5eeead6971
#   Stored in directory: C:\Users\schre\AppData\Local\Temp\pip-ephem-wheel-cache-9i5m2vhs\wheels\72\c7\76\aeff59c869a7cf6a37b4d233323dc59ec924e057ccc0893369
# Successfully built bregClust
# Installing collected packages: bregClust
# Successfully installed bregClust-1.0
#   Running command git clone --filter=blob:none --quiet https://github.com/FelipeSchreiber/BregmanClustering.git 'C:\Users\schre\AppData\Local\Temp\pip-req-build-dvyvlste'
# Collecting torch_geometric
#   Downloading torch_geometric-2.3.1.tar.gz (661 kB)
#                                               0.0/661.6 kB ? eta -:--:--
#      -------------------                    337.9/661.6 kB 7.0 MB/s eta 0:00:01
#      ----------------------------------     593.9/661.6 kB 6.2 MB/s eta 0:00:01
#      -------------------------------------  655.4/661.6 kB 5.9 MB/s eta 0:00:01
#      -------------------------------------  655.4/661.6 kB 5.9 MB/s eta 0:00:01
#      -------------------------------------- 661.6/661.6 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm in c:\users\schre\.conda\envs\pydml\lib\site-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: numpy in c:\users\schre\.conda\envs\pydml\lib\site-packages (from torch_geometric) (1.24.3)
# Collecting scipy (from torch_geometric)
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#                                               0.0/42.2 MB ? eta -:--:--
#                                               0.3/42.2 MB 10.2 MB/s eta 0:00:05
#                                               0.5/42.2 MB 6.6 MB/s eta 0:00:07
#                                               0.8/42.2 MB 6.0 MB/s eta 0:00:07
#                                               1.0/42.2 MB 5.5 MB/s eta 0:00:08
#      -                                        1.2/42.2 MB 5.6 MB/s eta 0:00:08
#      -                                        1.5/42.2 MB 5.4 MB/s eta 0:00:08
#      -                                        1.7/42.2 MB 5.4 MB/s eta 0:00:08
#      -                                        2.0/42.2 MB 5.4 MB/s eta 0:00:08
#      -                                        2.1/42.2 MB 5.2 MB/s eta 0:00:08
#      --                                       2.3/42.2 MB 5.0 MB/s eta 0:00:09
#      --                                       2.5/42.2 MB 4.8 MB/s eta 0:00:09
#      --                                       2.6/42.2 MB 4.7 MB/s eta 0:00:09
#      --                                       3.0/42.2 MB 4.9 MB/s eta 0:00:08
#      ---                                      3.2/42.2 MB 4.8 MB/s eta 0:00:09
#      ---                                      3.4/42.2 MB 4.8 MB/s eta 0:00:09
#      ------------                             2.6/8.3 MB 7.5 MB/s eta 0:00:01
#      -------------                            2.8/8.3 MB 6.7 MB/s eta 0:00:01
#      ---------------                          3.2/8.3 MB 6.7 MB/s eta 0:00:01
#      ----------------                         3.5/8.3 MB 6.7 MB/s eta 0:00:01
#      --------------------                     4.1/8.3 MB 6.8 MB/s eta 0:00:01
#      ---------------------                    4.5/8.3 MB 6.5 MB/s eta 0:00:01
#      -----------------------                  4.8/8.3 MB 6.4 MB/s eta 0:00:01
#      -------------------------                5.2/8.3 MB 6.5 MB/s eta 0:00:01
#      --------------------------               5.5/8.3 MB 6.5 MB/s eta 0:00:01
#      ---------------------------              5.8/8.3 MB 6.3 MB/s eta 0:00:01
#      ----------------------------             6.0/8.3 MB 6.2 MB/s eta 0:00:01
#      ------------------------------           6.3/8.3 MB 6.2 MB/s eta 0:00:01
#      -------------------------------          6.5/8.3 MB 6.3 MB/s eta 0:00:01
#      ---------------------------------        6.9/8.3 MB 6.4 MB/s eta 0:00:01
#      -----------------------------------      7.3/8.3 MB 6.4 MB/s eta 0:00:01
#      ------------------------------------     7.5/8.3 MB 6.3 MB/s eta 0:00:01
#      -------------------------------------    7.8/8.3 MB 6.3 MB/s eta 0:00:01
#      ---------------------------------------  8.1/8.3 MB 6.3 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------- 8.3/8.3 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.8.0 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from jinja2->torch_geometric) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from requests->torch_geometric) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from requests->torch_geometric) (2022.12.7)
# Collecting joblib>=1.1.1 (from scikit-learn->torch_geometric)
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->torch_geometric)
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: colorama in c:\users\schre\.conda\envs\pydml\lib\site-packages (from tqdm->torch_geometric) (0.4.6)
# Building wheels for collected packages: torch_geometric
#   Building wheel for torch_geometric (pyproject.toml): started
#   Building wheel for torch_geometric (pyproject.toml): finished with status 'done'
#   Created wheel for torch_geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910500 sha256=5f23897036b6336ca2dccc165e23ba04f37bbb084d4d0a80d07f1cb18c0ee774
#   Stored in directory: c:\users\schre\appdata\local\pip\cache\wheels\ff\6c\d6\f131acff9176ff91cb7ce97ddcd7170182c99533bf31c86a1d
# Successfully built torch_geometric
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, torch_geometric
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2 scipy-1.10.1 threadpoolctl-3.1.0 torch_geometric-2.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bregclust 1.0 requires rpy2==3.5.1, which is not installed.
# bregclust 1.0 requires joblib~=1.1.0, but you have joblib 1.2.0 which is incompatible.
# bregclust 1.0 requires numpy==1.24.2, but you have numpy 1.24.3 which is incompatible.
# Collecting rpy2==3.5.1
#   Using cached rpy2-3.5.1.tar.gz (201 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cffi>=1.10.0 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from rpy2==3.5.1) (1.15.1)
# Requirement already satisfied: jinja2 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from rpy2==3.5.1) (3.1.2)
# Requirement already satisfied: pytz in c:\users\schre\.conda\envs\pydml\lib\site-packages (from rpy2==3.5.1) (2023.3)
# Collecting tzlocal (from rpy2==3.5.1)
#   Using cached tzlocal-4.3-py3-none-any.whl (20 kB)
# Requirement already satisfied: pycparser in c:\users\schre\.conda\envs\pydml\lib\site-packages (from cffi>=1.10.0->rpy2==3.5.1) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\schre\.conda\envs\pydml\lib\site-packages (from jinja2->rpy2==3.5.1) (2.1.2)
# Collecting pytz-deprecation-shim (from tzlocal->rpy2==3.5.1)
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tzdata in c:\users\schre\.conda\envs\pydml\lib\site-packages (from tzlocal->rpy2==3.5.1) (2023.3)
# Collecting backports.zoneinfo (from tzlocal->rpy2==3.5.1)
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Building wheels for collected packages: rpy2
#   Building wheel for rpy2 (setup.py): started
#   Building wheel for rpy2 (setup.py): finished with status 'done'
#   Created wheel for rpy2: filename=rpy2-3.5.1-py3-none-any.whl size=205906 sha256=129c00aa0ced78f612a074353d52b2dc85f43fbdd1cdb575f5b07d5a54979b50
#   Stored in directory: c:\users\schre\appdata\local\pip\cache\wheels\6b\40\7d\f63e87fd83e8b99ee837c8e3489081c4b3489134bc520235ed
# Successfully built rpy2
# Installing collected packages: backports.zoneinfo, pytz-deprecation-shim, tzlocal, rpy2
# Successfully installed backports.zoneinfo-0.2.1 pytz-deprecation-shim-0.1.0.post0 rpy2-3.5.1 tzlocal-4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bregclust 1.0 requires joblib~=1.1.0, but you have joblib 1.2.0 which is incompatible.
# bregclust 1.0 requires numpy==1.24.2, but you have numpy 1.24.3 which is incompatible.

# %%
print(platform)
import BregmanTests
BregmanTests.__path__
# Out:
# win32
# ['C:\\Users\\schre\\.conda\\envs\\pydml\\lib\\site-packages\\BregmanTests']

# %%
from BregmanTests.benchmark import *
n_average = 1
n = 300
n_clusters = 3
d = 1
sizes = [ n // n_clusters ]*np.ones( n_clusters, dtype = int )
# Out:
# Downloading packages from github...
#
# Installing R packages...
#  This step takes about 5 min...
#
#
#     WARNING: The R package "reticulate" does not
#     consider that it could be called from a Python process. This
#     results in a quasi-obligatory segfault when rpy2 is evaluating
#     R code using it. On the hand, rpy2 is accounting for the
#     fact that it might already be running embedded in a Python
#     process. This is why:
#     - Python -> rpy2 -> R -> reticulate: crashes
#     - R -> reticulate -> Python -> rpy2: works
#
#     The issue with reticulate is tracked here:
#     https://github.com/rstudio/reticulate/issues/208

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
attributes_distribution = "poisson"
edge_distribution = "bernoulli"
weight_distribution = "gaussian"
d_range = np.arange(1,5,3)
mu_range = np.linspace(0,5,2)
att_centers = np.arange(1,4).reshape(-1,1)
BregmanBenchmark(att_variance=1,
                    attributes_distribution=attributes_distribution,
                    weight_variance=1,
                    weight_distribution=weight_distribution,
                    edge_distribution=edge_distribution,
                    att_centers=att_centers,
                    run_gpu=True
                  )\
                  .run_2_2(n_average=10,
                            cluster_sizes=sizes,
                             d_range = d_range,
                             mu_range = mu_range,
                             dense=True,
                             binary=False)
#!cp "/content/contour_plot_2_2.jpeg" "/content/drive/MyDrive"
# Out:
# 0it [00:00, ?it/s]
# Initialisation chosen from the attributes
# 0it [01:11, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#       5 mu_range = np.linspace(0,5,2)
#       6 att_centers = np.arange(1,4).reshape(-1,1)
# ----> 7 BregmanBenchmark(att_variance=1,
#       8                     attributes_distribution=attributes_distribution,
#       9                     weight_variance=1,
#      10                     weight_distribution=weight_distribution,
#      11                     edge_distribution=edge_distribution,
#      12                     att_centers=att_centers,
#      13                     run_gpu=True
#      14                   )\
#      15                   .run_2_2(n_average=10,
#      16                             cluster_sizes=sizes,
#      17                              d_range = d_range,
#      18                              mu_range = mu_range,
#      19                              dense=True,
#      20                              binary=False)
#      21 #!cp "/content/contour_plot_2_2.jpeg" "/content/drive/MyDrive"
#
# File ~\.conda\envs\pydml\lib\site-packages\BregmanTests\benchmark.py:445, in BregmanBenchmark.run_2_2(self, n_average, cluster_sizes, d_range, mu_range, dense, binary)
#     439 X = X.reshape(n,n,1)
#     440 model = self.model_(n_clusters=n_clusters,\
#     441                     attributeDistribution=self.attributes_distribution_name,\
#     442                     edgeDistribution=self.edge_distribution_name,\
#     443                     weightDistribution=self.weight_distribution_name
#     444                     )
# --> 445 z_pred_both = model.fit(A,X,Y).predict( X, Y )
#     446 #chernoff_graph_labels = model.memberships_from_graph
#     447 #chernoff_att_labels = model.memberships_from_attributes
#     448 aris_both.append( adjusted_rand_score( z_true, z_pred_both ) )
#
# File ~\.conda\envs\pydml\lib\site-packages\BregmanClusteringTorch\torch_models.py:123, in BregmanEdgeClusteringTorch.fit(self, A, X, Y, Z_init)
#     121 self.graph_means = self.computeGraphMeans(A,self.predicted_memberships).to(device)
#     122 self.edge_means = self.computeEdgeMeans(X,self.predicted_memberships).to(device)
# --> 123 new_memberships = self.assignments( A, X, Y ).to(device)
#     124 convergence = True
#     125 iteration = 0
#
# File ~\.conda\envs\pydml\lib\site-packages\BregmanClusteringTorch\torch_models.py:296, in BregmanEdgeClusteringTorch.assignments(self, A, X, Y)
#     293 z = torch.zeros( (Y.shape[ 0 ],self.n_clusters))
#     294 #H = self.attribute_divergence( Y, self.attribute_means )
#     295 H = self.reduce_by(
# --> 296             self.attribute_divergence(Y[:,None], self.attribute_means[None,:]),
#     297             dim=-1
#     298 )
#     299 for node in range( z.shape[0] ):
#     300     k = self.singleNodeAssignment( A, X, H, node )
#
# File ~\.conda\envs\pydml\lib\site-packages\BregmanClusteringTorch\torch_divergences.py:34, in relative_entropy(X, M)
#      33 def relative_entropy(X,M):
# ---> 34     total = X*torch.log(X/M) + M - X
#      35     return total
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, privateuseone:0 and cpu!

# %%
attributes_distribution = "gaussian"
edge_distribution = "bernoulli"
weight_distribution = "exponential"
a_range = np.linspace(5,13,10)
r_range = np.linspace(0,0.62,10)*np.log(n)
BregmanBenchmark(att_variance=1,
                    attributes_distribution=attributes_distribution,
                    weight_variance=1,
                    weight_distribution=weight_distribution,
                    edge_distribution=edge_distribution,
                    run_gpu=True)\
                  .run_2_1(n_average=10,
                            cluster_sizes=sizes,
                            b=5,
                            a_range= a_range,
                            r_range = r_range,
                            dense=False,
                            binary=True,
                            plot_3d=False)
#!cp "/content/contour_plot_2_1.jpeg" "/content/drive/MyDrive"

# %%
attributes_distribution = "poisson"
edge_distribution = "bernoulli"
weight_distribution = "exponential"
d_range = np.arange(1,5)
a_range = np.linspace(5,13,10)
lambda_range = np.arange(1,6)
att_centers = np.arange(1,4).reshape(-1,1)
BregmanBenchmark(att_variance=1,
                    attributes_distribution=attributes_distribution,
                    weight_variance=1,
                    weight_distribution=weight_distribution,
                    edge_distribution=edge_distribution,
                    att_centers=att_centers,
                    run_gpu=True
                 )\
                  .run_2_3(n_average=10,
                            cluster_sizes=sizes,
                            d_range= d_range,
                            lambda_range = lambda_range,
                            a_range = a_range,
                            b = 5,
                            dense=False,
                            binary=False)
# !cp "/content/contour_plot_2_3.jpeg" "/content/drive/MyDrive"
